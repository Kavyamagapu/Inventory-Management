# %%
import json

fd = open("product.json",'r')
r = fd.read()
fd.close()
records = json.loads(r)

# %%
print ("----------------------")
print("1 - View Items")
print("2 - Buy Items")
print("3 - Add new Items")
print("4 - Exit")
print ("----------------------")

ch = int(input("Enter your choice:"))

    
if(ch==1):
    #For viewing Products
    for i in records:
        print(i,records [i])

elif(ch==2):   #For buying Products
    
    ui_product = str(input("Enter the product ID:"))
    ui_quantity = int(input("Enter the quantity:"))



    print("***************************")
    print("product:",records[ui_product]['product'])
    print("price:", records [ui_product]['price'])


    print("***************************")
    print("Billing Amount :",records[ui_product]['price'] *ui_quantity) 
 
    print("THANKS FOR VISITING!")
    records [ui_product]['quantity']=records[ui_product]['quantity']-ui_quantity

    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
elif(ch==3):
    prod_id = str(input("Enter product ID:"))
    product = str(input("Enter name:"))
    price = int(input ("Enter price:"))
    quantity = int(input("Enter quantity:"))
    records[prod_id] = {'product': product,'price':price,'quantity': quantity}
    
    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
    
else:
    print("THANKS FOR VISITING!")
# Out:
# ----------------------
# 1 - View Items
# 2 - Buy Items
# 3 - Add new Items
# 4 - Exit
# ----------------------
# Enter your choice: 1
# 101 {'price': 45, 'product': 'Cake', 'quantity': 50}
# 102 {'price': 10, 'product': 'Five Star', 'quantity': 45}
# 103 {'price': 25, 'product': 'Ice Cream', 'quantity': 30}
# 104 {'price': 30, 'product': 'Milk', 'quantity': 40}
# 105 {'price': 35, 'product': 'Biscuits', 'quantity': 60}
# 106 {'price': 15, 'product': 'Maggie', 'quantity': 50}
# 107 {'price': 25, 'product': 'Chips', 'quantity': 60}
# 108 {'price': 25, 'product': 'Lays', 'quantity': 40}
# 109 {'price': 50, 'product': 'Kaju Cookies', 'quantity': 30}
# 110 {'price': 15, 'product': 'Munch', 'quantity': 50}
# 111 {'price': 15, 'product': 'Kit kat', 'quantity': 50}
# 112 {'price': 25, 'product': 'Gems', 'quantity': 60}
# 113 {'price': 45, 'product': 'Kinder joy', 'quantity': 45}
# 114 {'price': 10, 'product': 'parle G', 'quantity': 20}
# ...

# %%
print ("----------------------")
print("1 - View Items")
print("2 - Buy Items")
print("3 - Add new Items")
print("4 - Exit")
print ("----------------------")

ch = int(input("Enter your choice:"))

    
if(ch==1):
    #For viewing Products
    for i in records:
        print(i,records [i])

elif(ch==2):   #For buying Products
    
    ui_product = str(input("Enter the product ID:"))
    ui_quantity = int(input("Enter the quantity:"))



    print("***************************")
    print("product:",records[ui_product]['product'])
    print("price:", records [ui_product]['price'])


    print("***************************")
    print("Billing Amount :",records[ui_product]['price'] *ui_quantity) 
 
    print("THANKS FOR VISITING!")
    records [ui_product]['quantity']=records[ui_product]['quantity']-ui_quantity

    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
elif(ch==3):
    prod_id = str(input("Enter product ID:"))
    product = str(input("Enter name:"))
    price = int(input ("Enter price:"))
    quantity = int(input("Enter quantity:"))
    records[prod_id] = {'product': product,'price':price,'quantity': quantity}
    
    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
    
else:
    print("THANKS FOR VISITING!")
# Out:
# ----------------------
# 1 - View Items
# 2 - Buy Items
# 3 - Add new Items
# 4 - Exit
# ----------------------
# Enter your choice: 2
# Enter the product ID: 124
# Enter the quantity: 5
# ***************************
# product: Face wash
# price: 35
# ***************************
# Billing Amount : 175
# THANKS FOR VISITING!

# %%
print ("----------------------")
print("1 - View Items")
print("2 - Buy Items")
print("3 - Add new Items")
print("4 - Exit")
print ("----------------------")

ch = int(input("Enter your choice:"))

    
if(ch==1):
    #For viewing Products
    for i in records:
        print(i,records [i])

elif(ch==2):   #For buying Products
    
    ui_product = str(input("Enter the product ID:"))
    ui_quantity = int(input("Enter the quantity:"))



    print("***************************")
    print("product:",records[ui_product]['product'])
    print("price:", records [ui_product]['price'])


    print("***************************")
    print("Billing Amount :",records[ui_product]['price'] *ui_quantity) 
 
    print("THANKS FOR VISITING!")
    records [ui_product]['quantity']=records[ui_product]['quantity']-ui_quantity

    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
elif(ch==3):
    prod_id = str(input("Enter product ID:"))
    product = str(input("Enter name:"))
    price = int(input ("Enter price:"))
    quantity = int(input("Enter quantity:"))
    records[prod_id] = {'product': product,'price':price,'quantity': quantity}
    
    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
    
else:
    print("THANKS FOR VISITING!")
# Out:
# ----------------------
# 1 - View Items
# 2 - Buy Items
# 3 - Add new Items
# 4 - Exit
# ----------------------
# Enter your choice: 3
# Enter product ID: 132
# Enter name: Mango
# Enter price: 30
# Enter quantity: 40

# %%
print ("----------------------")
print("1 - View Items")
print("2 - Buy Items")
print("3 - Add new Items")
print("4 - Exit")
print ("----------------------")

ch = int(input("Enter your choice:"))

    
if(ch==1):
    #For viewing Products
    for i in records:
        print(i,records [i])

elif(ch==2):   #For buying Products
    
    ui_product = str(input("Enter the product ID:"))
    ui_quantity = int(input("Enter the quantity:"))



    print("***************************")
    print("product:",records[ui_product]['product'])
    print("price:", records [ui_product]['price'])


    print("***************************")
    print("Billing Amount :",records[ui_product]['price'] *ui_quantity) 
 
    print("THANKS FOR VISITING!")
    records [ui_product]['quantity']=records[ui_product]['quantity']-ui_quantity

    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
elif(ch==3):
    prod_id = str(input("Enter product ID:"))
    product = str(input("Enter name:"))
    price = int(input ("Enter price:"))
    quantity = int(input("Enter quantity:"))
    records[prod_id] = {'product': product,'price':price,'quantity': quantity}
    
    js = json.dumps(records)
    fd = open("product.json",'w')
    fd.write(js)
    fd.close()
    
    
else:
    print("THANKS FOR VISITING!")
# Out:
# ----------------------
# 1 - View Items
# 2 - Buy Items
# 3 - Add new Items
# 4 - Exit
# ----------------------
# Enter your choice: 4
# THANKS FOR VISITING!
